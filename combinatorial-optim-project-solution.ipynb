# %% [markdown]
# # Combinatorial optimization with Rydberg quantum computers
#
# This project will explore how quantum computers can be used to solve combinatorial optimization problems.
#
#
# We will focus on two approaches: one with gate-based (aka digital) quantum computers, one with analog quantum computers (aka quantum simulators).
#
#
#
# We will go through various steps:
# 1. convert the optimization problem to the search of the ground state of a Hamiltonian
# Design a quantum algorithm to find the ground state
# 2. analog algorithms
# 3. gate-based algorithms
#
#
# This will be done with Rydberg quantum computers, as described in the following research article: http://arxiv.org/abs/1808.10816.
#
#
# ## Quantum programming environment
#
# To execute the quantum programs, you will need to install the Python library called **myQLM** on your laptop. It can be installed by running the command
#
# ``pip install myqlm``
#
# Then, you need to clone the course's repository to have access to the notebook and some helper functions:
#
# ``git clone https://github.com/tayral/phy580_2025``
#
# It is highly advised to use the online documentation of myQLM at https://myqlm.github.io.
#
#
# Should you encounter problems with the installation (which may happen for Mac users using Anaconda), you can instead use "myBinder" to run the computations:
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/tayral/phy580_2025/)
#
# ... and open the ``combinatorial-optim-project.ipynb`` notebook.

# %%
# optional, only for Google colab

# !pip install myqlm
# !git clone https://github.com/tayral/phy580_2025.git
# %cd phy580_2025
# !ls
# Out:
# Collecting myqlm
#   Downloading myqlm-1.11.2-py3-none-any.whl.metadata (3.1 kB)
# Collecting qat-comm==1.7.0 (from myqlm)
#   Downloading qat_comm-1.7.0-cp39-cp39-manylinux_2_34_x86_64.whl.metadata (1.6 kB)
# Collecting qat-core==1.11.0 (from myqlm)
#   Downloading qat_core-1.11.0-cp39-cp39-manylinux_2_34_x86_64.whl.metadata (1.8 kB)
# Collecting qat-devices==0.4.0 (from myqlm)
#   Downloading qat_devices-0.4.0-cp39-cp39-manylinux_2_34_x86_64.whl.metadata (1.7 kB)
# Collecting qat-fusion==0.2.0 (from myqlm)
#   Downloading qat_fusion-0.2.0-cp39-cp39-manylinux_2_34_x86_64.whl.metadata (1.6 kB)
# Collecting qat-lang==3.2.0 (from myqlm)
#   Downloading qat_lang-3.2.0-cp39-cp39-manylinux_2_34_x86_64.whl.metadata (1.6 kB)
# Collecting qat-anapli==0.1.0 (from myqlm)
#   Downloading qat_anapli-0.1.0-cp39-cp39-manylinux_2_34_x86_64.whl.metadata (1.7 kB)
# Collecting qat-variational==1.6.0 (from myqlm)
#   Downloading qat_variational-1.6.0-cp39-cp39-manylinux_2_34_x86_64.whl.metadata (1.7 kB)
# Collecting qat-pbo==1.5.0 (from myqlm)
#   Downloading qat_pbo-1.5.0-cp39-cp39-manylinux_2_34_x86_64.whl.metadata (1.6 kB)
# Collecting qat-nnize==1.3.0 (from myqlm)
#   Downloading qat_nnize-1.3.0-cp39-cp39-manylinux_2_34_x86_64.whl.metadata (1.6 kB)
# Collecting qat-synthopline==0.4.0 (from myqlm)
#   Downloading qat_synthopline-0.4.0-cp39-cp39-manylinux_2_34_x86_64.whl.metadata (1.8 kB)
# Collecting qlmaas==1.11.2 (from myqlm)
#   Downloading qlmaas-1.11.2-cp39-cp39-manylinux_2_34_x86_64.whl.metadata (1.9 kB)
# Collecting myqlm-clinalg==0.3.0 (from myqlm)
#   Downloading myqlm_clinalg-0.3.0-cp39-cp39-manylinux_2_34_x86_64.whl.metadata (1.3 kB)
# Collecting myqlm-contrib==1.10.0 (from myqlm)
#   Downloading myqlm_contrib-1.10.0-py3-none-any.whl.metadata (1.1 kB)
# Collecting myqlm-fermion==1.2.0 (from myqlm)
#   Downloading myqlm_fermion-1.2.0-py3-none-any.whl.metadata (2.0 kB)
# Collecting myqlm-simulators==1.10.1 (from myqlm)
#   Downloading myqlm_simulators-1.10.1-py3-none-any.whl.metadata (1.2 kB)
# Requirement already satisfied: networkx in /usr/local/qaptiva/python_references/ref39/lib/python3.9/site-packages (from myqlm-contrib==1.10.0->myqlm) (3.1)
# Requirement already satisfied: anytree in /usr/local/qaptiva/python_references/ref39/lib/python3.9/site-packages (from myqlm-fermion==1.2.0->myqlm) (2.12.1)
# Requirement already satisfied: bitstring in /usr/local/qaptiva/python_references/ref39/lib/python3.9/site-packages (from myqlm-fermion==1.2.0->myqlm) (4.2.3)
# Requirement already satisfied: numpy~=1.0 in /home/tayral/.local/lib/python3.9/site-packages (from myqlm-fermion==1.2.0->myqlm) (1.26.4)
# Requirement already satisfied: scipy in /usr/local/qaptiva/python_references/ref39/lib64/python3.9/site-packages (from myqlm-fermion==1.2.0->myqlm) (1.13.1)
# Requirement already satisfied: tqdm in /usr/local/qaptiva/python_references/ref39/lib/python3.9/site-packages (from myqlm-fermion==1.2.0->myqlm) (4.67.1)
# Requirement already satisfied: matplotlib in /usr/local/qaptiva/python_references/ref39/lib64/python3.9/site-packages (from qat-anapli==0.1.0->myqlm) (3.9.3)
# Requirement already satisfied: thrift==0.21.0 in /usr/local/qaptiva/python_references/ref39/lib64/python3.9/site-packages (from qat-comm==1.7.0->myqlm) (0.21.0)
# Requirement already satisfied: wand in /usr/local/qaptiva/python_references/ref39/lib/python3.9/site-packages (from qat-core==1.11.0->myqlm) (0.6.13)
# Requirement already satisfied: dill in /usr/local/qaptiva/python_references/ref39/lib/python3.9/site-packages (from qat-core==1.11.0->myqlm) (0.3.9)
# Requirement already satisfied: Pillow in /usr/local/qaptiva/python_references/ref39/lib64/python3.9/site-packages (from qat-core==1.11.0->myqlm) (11.0.0)
# Requirement already satisfied: svgwrite in /usr/local/qaptiva/python_references/ref39/lib/python3.9/site-packages (from qat-core==1.11.0->myqlm) (1.4.3)
# Requirement already satisfied: jax[cpu] in /home/tayral/.local/lib/python3.9/site-packages (from qat-core==1.11.0->myqlm) (0.4.29)
# Requirement already satisfied: IPython in /usr/local/qaptiva/python_references/ref39/lib/python3.9/site-packages (from qat-core==1.11.0->myqlm) (8.18.1)
# Requirement already satisfied: ply==3.11 in /usr/local/qaptiva/python_references/ref39/lib/python3.9/site-packages (from qat-lang==3.2.0->myqlm) (3.11)
# Requirement already satisfied: stim in /usr/local/qaptiva/python_references/ref39/lib64/python3.9/site-packages (from qat-synthopline==0.4.0->myqlm) (1.14.0)
# Requirement already satisfied: rich in /usr/local/qaptiva/python_references/ref39/lib/python3.9/site-packages (from qat-synthopline==0.4.0->myqlm) (13.9.4)
# Requirement already satisfied: prompt_toolkit in /usr/local/qaptiva/python_references/ref39/lib/python3.9/site-packages (from qlmaas==1.11.2->myqlm) (3.0.48)
# Requirement already satisfied: prettytable in /usr/local/qaptiva/python_references/ref39/lib/python3.9/site-packages (from qlmaas==1.11.2->myqlm) (3.12.0)
# Requirement already satisfied: pyOpenSSL in /usr/local/qaptiva/python_references/ref39/lib/python3.9/site-packages (from qlmaas==1.11.2->myqlm) (24.3.0)
# Requirement already satisfied: cffi in /usr/local/qaptiva/python_references/ref39/lib64/python3.9/site-packages (from qlmaas==1.11.2->myqlm) (1.17.1)
# Collecting qat-hardware>=1.5.0 (from qlmaas==1.11.2->myqlm)
#   Downloading qat_hardware-1.5.0-cp39-cp39-manylinux_2_34_x86_64.whl.metadata (1.6 kB)
# Collecting qat-quops>=1.4.0 (from qlmaas==1.11.2->myqlm)
#   Downloading qat_quops-1.4.0-cp39-cp39-manylinux_2_34_x86_64.whl.metadata (1.6 kB)
# Requirement already satisfied: packaging in /usr/local/qaptiva/python_references/ref39/lib/python3.9/site-packages (from qlmaas==1.11.2->myqlm) (23.2)
# Requirement already satisfied: six>=1.7.2 in /usr/local/qaptiva/python_references/ref39/lib/python3.9/site-packages (from thrift==0.21.0->qat-comm==1.7.0->myqlm) (1.16.0)
# Requirement already satisfied: qutip in /usr/local/qaptiva/python_references/ref39/lib64/python3.9/site-packages (from qat-hardware>=1.5.0->qlmaas==1.11.2->myqlm) (5.0.4)
# Requirement already satisfied: cvxpy in /usr/local/qaptiva/python_references/ref39/lib64/python3.9/site-packages (from qat-quops>=1.4.0->qlmaas==1.11.2->myqlm) (1.6.0)
# Requirement already satisfied: bitarray<3.0.0,>=2.9.0 in /usr/local/qaptiva/python_references/ref39/lib64/python3.9/site-packages (from bitstring->myqlm-fermion==1.2.0->myqlm) (2.9.3)
# Requirement already satisfied: pycparser in /usr/local/qaptiva/python_references/ref39/lib/python3.9/site-packages (from cffi->qlmaas==1.11.2->myqlm) (2.22)
# Requirement already satisfied: decorator in /usr/local/qaptiva/python_references/ref39/lib/python3.9/site-packages (from IPython->qat-core==1.11.0->myqlm) (5.1.1)
# Requirement already satisfied: jedi>=0.16 in /usr/local/qaptiva/python_references/ref39/lib/python3.9/site-packages (from IPython->qat-core==1.11.0->myqlm) (0.19.2)
# Requirement already satisfied: matplotlib-inline in /usr/local/qaptiva/python_references/ref39/lib/python3.9/site-packages (from IPython->qat-core==1.11.0->myqlm) (0.1.7)
# Requirement already satisfied: pygments>=2.4.0 in /usr/local/qaptiva/python_references/ref39/lib/python3.9/site-packages (from IPython->qat-core==1.11.0->myqlm) (2.18.0)
# Requirement already satisfied: stack-data in /usr/local/qaptiva/python_references/ref39/lib/python3.9/site-packages (from IPython->qat-core==1.11.0->myqlm) (0.6.3)
# Requirement already satisfied: traitlets>=5 in /usr/local/qaptiva/python_references/ref39/lib/python3.9/site-packages (from IPython->qat-core==1.11.0->myqlm) (5.14.3)
# Requirement already satisfied: typing-extensions in /usr/local/qaptiva/python_references/ref39/lib/python3.9/site-packages (from IPython->qat-core==1.11.0->myqlm) (4.12.2)
# Requirement already satisfied: exceptiongroup in /usr/local/qaptiva/python_references/ref39/lib/python3.9/site-packages (from IPython->qat-core==1.11.0->myqlm) (1.2.2)
# Requirement already satisfied: pexpect>4.3 in /usr/local/qaptiva/python_references/ref39/lib/python3.9/site-packages (from IPython->qat-core==1.11.0->myqlm) (4.9.0)
# Requirement already satisfied: wcwidth in /usr/local/qaptiva/python_references/ref39/lib/python3.9/site-packages (from prompt_toolkit->qlmaas==1.11.2->myqlm) (0.2.13)
# Requirement already satisfied: ml-dtypes>=0.4.0 in /home/tayral/.local/lib/python3.9/site-packages (from jax[cpu]->qat-core==1.11.0->myqlm) (0.4.0)
# Requirement already satisfied: opt-einsum in /usr/local/qaptiva/python_references/ref39/lib/python3.9/site-packages (from jax[cpu]->qat-core==1.11.0->myqlm) (3.4.0)
# Requirement already satisfied: importlib-metadata>=4.6 in /usr/local/qaptiva/python_references/ref39/lib/python3.9/site-packages (from jax[cpu]->qat-core==1.11.0->myqlm) (8.5.0)
# Requirement already satisfied: jaxlib==0.4.29 in /home/tayral/.local/lib/python3.9/site-packages (from jax[cpu]->qat-core==1.11.0->myqlm) (0.4.29)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/qaptiva/python_references/ref39/lib64/python3.9/site-packages (from matplotlib->qat-anapli==0.1.0->myqlm) (1.3.0)
# Requirement already satisfied: cycler>=0.10 in /usr/local/qaptiva/python_references/ref39/lib/python3.9/site-packages (from matplotlib->qat-anapli==0.1.0->myqlm) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/qaptiva/python_references/ref39/lib64/python3.9/site-packages (from matplotlib->qat-anapli==0.1.0->myqlm) (4.55.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/qaptiva/python_references/ref39/lib64/python3.9/site-packages (from matplotlib->qat-anapli==0.1.0->myqlm) (1.4.7)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/qaptiva/python_references/ref39/lib/python3.9/site-packages (from matplotlib->qat-anapli==0.1.0->myqlm) (3.2.0)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/qaptiva/python_references/ref39/lib/python3.9/site-packages (from matplotlib->qat-anapli==0.1.0->myqlm) (2.9.0.post0)
# Requirement already satisfied: importlib-resources>=3.2.0 in /usr/local/qaptiva/python_references/ref39/lib/python3.9/site-packages (from matplotlib->qat-anapli==0.1.0->myqlm) (6.4.5)
# Requirement already satisfied: cryptography<45,>=41.0.5 in /usr/local/qaptiva/python_references/ref39/lib64/python3.9/site-packages (from pyOpenSSL->qlmaas==1.11.2->myqlm) (44.0.0)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/qaptiva/python_references/ref39/lib/python3.9/site-packages (from rich->qat-synthopline==0.4.0->myqlm) (3.0.0)
# Requirement already satisfied: zipp>=3.20 in /usr/local/qaptiva/python_references/ref39/lib/python3.9/site-packages (from importlib-metadata>=4.6->jax[cpu]->qat-core==1.11.0->myqlm) (3.21.0)
# Requirement already satisfied: parso<0.9.0,>=0.8.4 in /usr/local/qaptiva/python_references/ref39/lib/python3.9/site-packages (from jedi>=0.16->IPython->qat-core==1.11.0->myqlm) (0.8.4)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/qaptiva/python_references/ref39/lib/python3.9/site-packages (from markdown-it-py>=2.2.0->rich->qat-synthopline==0.4.0->myqlm) (0.1.2)
# Requirement already satisfied: ptyprocess>=0.5 in /usr/local/qaptiva/python_references/ref39/lib/python3.9/site-packages (from pexpect>4.3->IPython->qat-core==1.11.0->myqlm) (0.7.0)
# Requirement already satisfied: osqp>=0.6.2 in /usr/local/qaptiva/python_references/ref39/lib64/python3.9/site-packages (from cvxpy->qat-quops>=1.4.0->qlmaas==1.11.2->myqlm) (0.6.7.post3)
# Requirement already satisfied: clarabel>=0.5.0 in /usr/local/qaptiva/python_references/ref39/lib64/python3.9/site-packages (from cvxpy->qat-quops>=1.4.0->qlmaas==1.11.2->myqlm) (0.9.0)
# Requirement already satisfied: scs>=3.2.4.post1 in /usr/local/qaptiva/python_references/ref39/lib64/python3.9/site-packages (from cvxpy->qat-quops>=1.4.0->qlmaas==1.11.2->myqlm) (3.2.7)
# Requirement already satisfied: executing>=1.2.0 in /usr/local/qaptiva/python_references/ref39/lib/python3.9/site-packages (from stack-data->IPython->qat-core==1.11.0->myqlm) (2.1.0)
# Requirement already satisfied: asttokens>=2.1.0 in /usr/local/qaptiva/python_references/ref39/lib/python3.9/site-packages (from stack-data->IPython->qat-core==1.11.0->myqlm) (2.4.1)
# Requirement already satisfied: pure-eval in /usr/local/qaptiva/python_references/ref39/lib/python3.9/site-packages (from stack-data->IPython->qat-core==1.11.0->myqlm) (0.2.3)
# Requirement already satisfied: qdldl in /usr/local/qaptiva/python_references/ref39/lib64/python3.9/site-packages (from osqp>=0.6.2->cvxpy->qat-quops>=1.4.0->qlmaas==1.11.2->myqlm) (0.1.7.post4)
# Downloading myqlm-1.11.2-py3-none-any.whl (2.2 kB)
# Downloading myqlm_clinalg-0.3.0-cp39-cp39-manylinux_2_34_x86_64.whl (730 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 730.5/730.5 kB 6.1 MB/s eta 0:00:00
# Downloading myqlm_contrib-1.10.0-py3-none-any.whl (13 kB)
# Downloading myqlm_fermion-1.2.0-py3-none-any.whl (90 kB)
# Downloading myqlm_simulators-1.10.1-py3-none-any.whl (19 kB)
# Downloading qat_anapli-0.1.0-cp39-cp39-manylinux_2_34_x86_64.whl (634 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 634.6/634.6 kB 10.7 MB/s eta 0:00:00
# Downloading qat_comm-1.7.0-cp39-cp39-manylinux_2_34_x86_64.whl (3.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.1/3.1 MB 8.8 MB/s eta 0:00:00a 0:00:01
# Downloading qat_core-1.11.0-cp39-cp39-manylinux_2_34_x86_64.whl (4.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.7/4.7 MB 12.6 MB/s eta 0:00:00a 0:00:01
# Downloading qat_devices-0.4.0-cp39-cp39-manylinux_2_34_x86_64.whl (329 kB)
# Downloading qat_fusion-0.2.0-cp39-cp39-manylinux_2_34_x86_64.whl (817 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 817.7/817.7 kB 16.8 MB/s eta 0:00:00
# Downloading qat_lang-3.2.0-cp39-cp39-manylinux_2_34_x86_64.whl (2.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.7/2.7 MB 15.2 MB/s eta 0:00:00
# Downloading qat_nnize-1.3.0-cp39-cp39-manylinux_2_34_x86_64.whl (737 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 737.5/737.5 kB 17.3 MB/s eta 0:00:00
# Downloading qat_pbo-1.5.0-cp39-cp39-manylinux_2_34_x86_64.whl (1.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 20.0 MB/s eta 0:00:00
# Downloading qat_synthopline-0.4.0-cp39-cp39-manylinux_2_34_x86_64.whl (2.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.7/2.7 MB 19.0 MB/s eta 0:00:00
# Downloading qat_variational-1.6.0-cp39-cp39-manylinux_2_34_x86_64.whl (1.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.8/1.8 MB 25.7 MB/s eta 0:00:00
# Downloading qlmaas-1.11.2-cp39-cp39-manylinux_2_34_x86_64.whl (2.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.8/2.8 MB 24.6 MB/s eta 0:00:00
# Downloading qat_hardware-1.5.0-cp39-cp39-manylinux_2_34_x86_64.whl (303 kB)
# Downloading qat_quops-1.4.0-cp39-cp39-manylinux_2_34_x86_64.whl (1.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.1/1.1 MB 24.0 MB/s eta 0:00:00
# Installing collected packages: qat-comm, qat-core, qat-lang, qat-fusion, qat-devices, qat-anapli, myqlm-contrib, qat-variational, qat-quops, qat-pbo, qat-hardware, myqlm-clinalg, qat-nnize, myqlm-simulators, qat-synthopline, qlmaas, myqlm-fermion, myqlm
# ERROR: Could not install packages due to an OSError: [Errno 30] Read-only file system: '/usr/local/qaptiva/python_references/ref39/lib/python3.9/site-packages/qat'
#
# Cloning into 'phy580_2025'...
# remote: Enumerating objects: 44, done.
# remote: Counting objects: 100% (44/44), done.
# remote: Compressing objects: 100% (32/32), done.
# remote: Total 44 (delta 13), reused 40 (delta 9), pack-reused 0 (from 0)
# Receiving objects: 100% (44/44), 1.88 MiB | 408.00 KiB/s, done.
# Resolving deltas: 100% (13/13), done.
# /home/tayral/work/x_enseignement/phy580/phy580_2025/phy580_2025
# analog_tutorial.ipynb	    hilbert_space.py  requirements.txt
# basic_qutip_qpu.py	    omalley_utils.py  result.py
# data			    postBuild	      runtime.txt
# depolarizing_plugin_vec.py  qpe_utils.py      tuto_utils.py
# digital_tutorial.ipynb	    qutip_tools.py
# dihydrogen-project.ipynb    README.md
# /usr/local/qaptiva/python_references/ref39/lib/python3.9/site-packages/IPython/core/magics/osm.py:417: UserWarning: using dhist requires you to install the `pickleshare` library.
#   self.shell.db['dhist'] = compress_dhist(dhist)[-100:]

# %% [markdown]
# ## 1. The Hamiltonian of the Maximum Independent Set problem
#
#
#
# <div class="alert alert-block alert-info">
#
# - Describe the maximum independent set problem as a constrained optimization problem.
#
# - How does one arrive at eq. (1)?
#
# - What is the naive (classical) cost of computing the ground state of $H$?
# </div>
#
# Describe this Hamiltonian with a myQLM ``Observable`` object, called ``H_target``. Use the ``get_matrix`` method to get the matrix representation of $H_\mathrm{target}$.
#
# Hint: to create the Hamiltonian, you will need to first create a graph object. Use the ``networkx`` library to create such graphs. For simplicity, you can start by using "d-regular graphs".
#
# <div class="alert alert-block alert-info">
# What is its size as a function of the size of the graph?
# </div>

# %%
import networkx as nx
import random
random.seed(2534)
size = 6
d = 3 # degree
graph = nx.generators.random_regular_graph(d, size)
nx.draw(graph, with_labels=True)

approx_sol = nx.approximation.maximum_independent_set(graph)
print(approx_sol)
# Out:
# {2, 4, 5}

# %%
U = 1.
from qat.core import Observable, Term
nqbits = size
# H_target = sum_i -n_i + U sum_ij n_i n_j
n = [Observable(nqbits, pauli_terms=[Term(-0.5, "Z", [qb])], constant_coeff=0.5) for qb in range(nqbits)]
H_target = -sum([n[i] for i in range(nqbits)])
for i,j in graph.edges():
    H_target += U* n[i]*n[j] 
    
print(H_target)
# Out:
# -0.75 * I^6 +
# 0.25 * (ZZ|[1, 2]) +
# 0.25 * (ZZ|[1, 5]) +
# -0.25 * (Z|[1]) +
# 0.25 * (ZZ|[1, 4]) +
# 0.25 * (ZZ|[2, 3]) +
# -0.25 * (Z|[2]) +
# 0.25 * (ZZ|[0, 2]) +
# 0.25 * (ZZ|[0, 4]) +
# -0.25 * (Z|[0]) +
# 0.25 * (ZZ|[0, 5]) +
# -0.25 * (Z|[4]) +
# 0.25 * (ZZ|[3, 4]) +
# -0.25 * (Z|[3]) +
# -0.25 * (Z|[5]) +
# 0.25 * (ZZ|[3, 5])

# %% [markdown]
# ### Exact solution
#
# To know how good our solution is, we need to find the optimal solution. Given $H_\mathrm{target}$, how do you extract the exact solution? What is the cost as a function of graph size?

# %%
import numpy as np
mat = H_target.to_matrix()
min_energy = np.min(mat.diagonal())

sol = np.argmin(mat.diagonal())
print(f"energy= {min_energy}, sol={sol}, bin={np.binary_repr(sol, width=size)}")
# Out:
# energy= (-3+0j), sol=11, bin=001011

# %% [markdown]
# This corresponds to {2,4,5}. This is indeed a MIS for the graph (there is no bigger set).

# %% [markdown]
# ## 2. Analog implementation for the Maximum Independent Set problem
#
# ### Part a: do the tutorial (analog_tutorial.ipynb)
#
# It explains how to send "analog" jobs to QPUs.
#
# ### Part b: adapt it for the Rydberg situation
#
# <div class="alert alert-block alert-info">
#
# - In a Rydberg processor, what is the Hamiltonian $H_\mathrm{resource}$ that can be implemented in practice (find it in the article)?
#
# - In the quantum adiabatic annealing method, what is the form $H_{QAA}$ of the time-dependent Hamiltonian that is needed? (what is $H_0$?)
#
# - Are $H_\mathrm{resource}$ and $H_{QAA}$ identical?
# </div>
#
#
# Write a ``Schedule`` that represents $H_{QAA}$ (for now, without consideration for the difference with the available resource Hamiltonian).

# %%
from qat.core import Schedule
from qat.core.variables import Variable

t = Variable("t", float)
tmax = 10.0

## define the Schedule
H0 = Observable(nqbits, pauli_terms=[Term(1.0, "X", [qb]) for qb in range(nqbits)])
schedule = Schedule(drive = [(1-t/tmax, H0), (t/tmax, H_target)], tmax=tmax)

schedule.display()

# %% [markdown]
# ### Part c: run the algorithm
#
# Now, use a "QPU" to run the Schedule and measure H_target at the end.

# %%
from basic_qutip_qpu import QutipQPU

qpu = QutipQPU() # a classical emulator of an analog QPU

# create a quantum job with a schedule and observable to be measured at the end.
job = schedule.to_job(psi_0 = "-"*nqbits, observable=H_target)

# run
res = qpu.submit(job)

# %%
times = [float(t) for t in res.value_data.keys()]
vals = [res.value_data[t].re for t in res.value_data.keys()]
import matplotlib.pyplot as plt
plt.plot(times, vals)
plt.ylabel(r"$\langle H_\mathrm{target} \rangle$")
plt.xlabel(r"$t$");

# %% [markdown]
# #### Studying of the role of the various parameters
#
# <div class="alert alert-block alert-info">
#
# - What happens if you increase the annealing time? (this parameter is defined in the ``Schedule``object)
#
# - How to read off the solution to the MIS problem? (Hint: use a job that samples the final distribution)
#
# </div>

# %%
def make_simulation(tmax):
    t = Variable("t", float)
    
    ## define the Schedule
    H0 = Observable(nqbits, pauli_terms=[Term(1.0, "X", [qb]) for qb in range(nqbits)])
    schedule = Schedule(drive = [(1-t/tmax, H0), (t/tmax, H_target)], tmax=tmax)
    qpu = QutipQPU() # a classical emulator of an analog QPU

    # create a quantum job with a schedule and observable to be measured at the end.
    job = schedule.to_job(psi_0 = "-"*nqbits, observable=H_target)
    
    # run
    res = qpu.submit(job)
    print(tmax, res.value)
    return res.value


tmax_list = np.linspace(1, 20, 5)
vals = [make_simulation(tmax) for tmax in tmax_list]
# Out:
# 1.0 -0.9637969176836694
# 5.75 -1.9007632863537949
# 10.5 -2.432223500768093
# 15.25 -2.759839287697204
# 20.0 -2.9131778593144526

# %%
plt.plot(tmax_list, vals, label = "annealing")
plt.plot(tmax_list, [min_energy]*len(tmax_list), '--k', label = "exact energy")
plt.ylabel("Final energy")
plt.xlabel("tmax")
plt.legend();

# %% [markdown]
# We see that as we increase the annealing duration, we get a final energy that is closer and closer to the energy of the exact solution.

# %%
t = Variable("t", float)
tmax = 25
## define the Schedule
H0 = Observable(nqbits, pauli_terms=[Term(1.0, "X", [qb]) for qb in range(nqbits)])
schedule = Schedule(drive = [(1-t/tmax, H0), (t/tmax, H_target)], tmax=tmax)
qpu = QutipQPU() # a classical emulator of an analog QPU

# create a quantum job with a schedule (without observable in order to sample from final state).
job = schedule.to_job(psi_0 = "-"*nqbits)
    
# run
res = qpu.submit(job)
for sample in res:
    if sample.probability > 0.1:
        print(sample.state, sample.probability)
# Out:
# |001011> 0.4848793032815895
# |110100> 0.4848793032815895

# %% [markdown]
# We see that two solutions {2,4,5} and {0, 1, 3} emerge.

# %% [markdown]
# #### More realistic simulation: with the true Hamiltonian of Rydbergs
#
# Now, we want to actually use $H_\mathrm{resource}$. For this we can tune $\Delta(t)$ and $\Omega(t)$ (see Eq. (2) in the article) so that $H_\mathrm{resource}(t)$ looks similar to $H_{QAA}(t)$.
#
# Remarks:
#
# - in QA, the starting state needs to be the GS of $H_0$. In a Rydberg platform, the initial state is always $|0,0,\dots,0\rangle$. How to tune $\Delta(t=0)$ so that the ground state is indeed $|0,0,\dots,0\rangle$?
#
# - in what types of graphs can Rydberg atoms actually implement?

# %% [markdown]
# #### Unit disk graph generation

# %%
from itertools import product


# create a unit-disk graph at random
def generate_unit_disk_graph(size, density, r):
    """
    Generate unit disk graph points
    Args:
        size (int): number of points
        density (float): number of points per unit square
        r (float): exclusion radius (no two points are closer than this radius)

    Returns:
        list (x,y)
    """
    L = np.sqrt(size/density)
    point_list = [(random.uniform(0, L), random.uniform(0, L))]
    while len(point_list) < size:
        x = random.uniform(0, L)
        y = random.uniform(0, L) 
        #print("proposing", x, y)
        old_point_list = point_list.copy()
        within_radius = False
        for x0, y0 in old_point_list:
            d = np.sqrt((x-x0)**2 + (y-y0)**2)
            if d < r:
                within_radius = True
        if not within_radius:
            #print("adding", x,y, d)
            point_list.append((x,y))
    return point_list

def make_nx_graph(point_list):
    """ make unit disk graph out of point list"""
    graph = nx.Graph()
    node_list, edge_list = [], []
    for i, (x,y) in enumerate(point_list):
        node_list.append(i)
    for ((i, (x1,y1)), (j, (x2, y2))) in product(enumerate(point_list), repeat=2): 
        d = np.sqrt((x1-x2)**2+(y1-y2)**2)
        if d<1 and d>0:
            edge_list.append((i,j))
    
    graph.add_nodes_from(node_list)
    graph.add_edges_from(edge_list)
    return graph

random.seed(143)
size = 10
density = 2.
r = 0.3 # exclusion radius

point_list = generate_unit_disk_graph(size, density, r)
graph = make_nx_graph(point_list)

# %%
nx.draw(graph, with_labels=True)

# %% [markdown]
# #### Annealing run

# %%
# draw a random UD graph
random.seed(255)
nqbits = 5
density = 2.
r = 0.3
point_list = generate_unit_disk_graph(nqbits, density, r)
graph = make_nx_graph(point_list)

nx.draw(graph, with_labels=True)

# %%
# build H_target
U = 1
n = [Observable(nqbits, pauli_terms=[Term(-0.5, "Z", [qb])], constant_coeff=0.5) for qb in range(nqbits)]
H_target = -sum([n[i] for i in range(nqbits)])
for i,j in graph.edges():
    H_target += U* n[i]*n[j] 

# do exact calculation to check
import numpy as np
mat = H_target.to_matrix()
min_energy = np.min(mat.diagonal())

sol = np.argmin(mat.diagonal())
print(f"energy= {min_energy}, sol={sol}, bin={np.binary_repr(sol, width=nqbits)}")
# Out:
# energy= (-2+0j), sol=5, bin=00101

# %%
# prepare annealing schedule
tmax = 40
t = Variable("t", float)

from qat.core.variables import sin
## define the Schedule
H_Rabi = Observable(nqbits, pauli_terms=[Term(1.0, "X", [qb]) for qb in range(nqbits)])
H_detuning = -sum([n[i] for i in range(nqbits)])
H_vdW = sum([1/((x1-x2)**2+(y1-y2)**2)**3* n[i]*n[j]
             for ((i,(x1,y1)), (j, (x2, y2))) in product(enumerate(point_list), repeat=2) if i != j]) 

schedule = Schedule(drive = [(sin(t*np.pi/tmax)**2, H_Rabi),
                             (4*(t/tmax -1/2) , H_detuning),
                             (1, H_vdW)
                            ],
                    tmax=tmax)

schedule.display()

# %%
qpu = QutipQPU(n_steps=1000) # a classical emulator of an analog QPU

# create a quantum job with a schedule and observable to be measured at the end.
job = schedule.to_job(observable=H_target)
    
# run
res = qpu.submit(job)
print(tmax, res.value)
# Out:
# 40 -1.9983630634365608

# %% [markdown]
# It makes sense!

# %%
times = [float(t) for t in res.value_data.keys()]
vals = [res.value_data[t].re for t in res.value_data.keys()]
import matplotlib.pyplot as plt
plt.plot(times, vals)
plt.ylabel(r"$\langle H_\mathrm{target} \rangle$")
plt.xlabel(r"$t$");

# %%
job = schedule.to_job() # sample mode 
    
# run
res = qpu.submit(job)
for sample in res:
    if sample.probability > 0.1:
        print(sample.state, sample.probability)
# Out:
# |10100> 0.5146676905861048
# |11000> 0.47245440352395185

# %% [markdown]
# <div class="alert alert-block alert-info">
# What do you observe?
# </div>
#
# Solutions {0, 2} and {0, 1} which are also admissible solutions.

# %% [markdown]
# ### Going beyond unit-disk graphs
#
#
# <div class="alert alert-block alert-info">
#
# - Is it possible to handle graphs which are not unit-disk graphs? How so? What additional assumptions do you need on the hardware?
#
# </div>

# %% [markdown]
# ## 3. Gate-based implementation for the MIS problem
#
#
# We now assume we can use the Rydberg atom platform as a digital (gate-based) platform.
#
# <div class="alert alert-block alert-info">
#
# - Under which conditions can one use a Rydberg platform as a gate-based quantum computer?
#
# </div>
#
#
# ### Prerequisite
#
# Do the myQLM tutorial on digital (gate-based) computation: ``digital_tutorial.ipynb``.
#
# ### QAOA algorithm
#
#
# <div class="alert alert-block alert-info">
#
# - Describe the QAOA algorithm for a general combinatorial optimization problem (look at appendix I.B.1 of the article)
#
# - What is the role of parameter $p$?
#
# - In your case, what energy are you tring to maximize?
#
# - What is the form of the ansatz circuit?
#
# </div>
#
# We are now going to implement QAOA with myQLM.
#
#
# #### Ansatz circuit
#
# Using the same graph you used before (e.g the d-regular graph above), construct a parametric quantum circuit (see the documentation here: https://myqlm.github.io/02_user_guide/01_write/01_digital_circuit/02_variational.html)

# %%
from qat.lang.AQASM import Program, H, RX

size = 10
d = 3 # degree
graph = nx.generators.random_regular_graph(d, size)

# prog = Program()
# ... create variables
# ... add gates depending on these variables

# var_circ = prog.to_circ()

# %% [markdown]
# ### Optimization
#
# In Qaptiva, the optimization is done with "plugins". They essentially perform the optimization of the parameters for a given cost function.

# %%
#### solution 
from qat.qpus import get_default_qpu
from qat.plugins import ScipyMinimizePlugin

qpu = get_default_qpu() # a classical emulator of gate-based QPUs.
plugin = ScipyMinimizePlugin(method="COBYLA",
                            tol=1e-5, 
                            options={"maxiter": 200})
stack = plugin | qpu

job = var_circ.to_job(observable = H_target) 
result = stack.submit(job)
print("Final energy:", result.value)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[20], line 11
#       6 plugin = ScipyMinimizePlugin(method="COBYLA",
#       7                             tol=1e-5,
#       8                             options={"maxiter": 200})
#       9 stack = plugin | qpu
# ---> 11 job = var_circ.to_job(observable = H_target)
#      12 result = stack.submit(job)
#      13 print("Final energy:", result.value)
#
# NameError: name 'var_circ' is not defined

# %%
import matplotlib.pyplot as plt
plt.plot(eval(result.meta_data["optimization_trace"]))
plt.xlabel("steps")
plt.ylabel("energy")
plt.show()

# %% [markdown]
# ### Reading off the solution
#
# The QAOA procedure yields a value of the optimized parameters, contained in the ``result`` variable (see ``result.meta_data`` field). We now want to recover the state corresponding to these optimized parameters, so that we can read the solution to the UDMIS problem.
#
# For this, we need to evaluate our parameterized quantum circuit ``var_circ`` on the optimized values of the variables.
# This can be achieved like this: if a circuit has a single variable ``toto``, then replacing occurrences of ``toto`` by its value (say 5) can be done via:
#
# ```python
# dic = {"toto" : 5.0}
# circ = var_circ(**dic)
# ```

# %%
# retrieving the parameters
# replacing in var_circ
# executing the circ on the QPU in "SAMPLE" mode (no observables)

# %% [markdown]
# ## 4. Conclusions
#
# <div class="alert alert-block alert-info">
#
# - What are the respective advantages and drawbacks of QA (analog) and QAOA (gate-based)?
#
# - Compared to the exact solution, how do quantum algorithms fare?
#
# </div>
#
# ## 5. Going beyond
#
# - Here, we have used for simplicity d-regular graphs. Repeat the experiments on actual unit-disk graphs (for this, think how to generate random unit-disk graphs
#
# - What do you expect the role of decoherence to be in both cases?
